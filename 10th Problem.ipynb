# %%
# !git clone https://github.com/mirayanali5/Deep-Learning-Lab.git
# %cd /content/Deep-Learning-Lab

# !ls CIFAR10_TIFF
# Out:
# fatal: destination path 'Deep-Learning-Lab' already exists and is not an empty directory.
# /content/Deep-Learning-Lab
# airplane  automobile  bird  cat  deer  dog  frog  horse  ship  truck

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, regularizers, optimizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import matplotlib.pyplot as plt
import numpy as np
import os
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

# %%
# Path to dataset
dataset_dir = "/content/Deep-Learning-Lab/CIFAR10_TIFF"

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.15,
    height_shift_range=0.15,
    shear_range=0.15,
    zoom_range=0.15,
    horizontal_flip=True,
    fill_mode='nearest',
    validation_split=0.2
)

train_generator = train_datagen.flow_from_directory(
    dataset_dir,
    target_size=(32, 32),
    batch_size=64,
    class_mode='categorical',
    subset='training'
)

val_generator = train_datagen.flow_from_directory(
    dataset_dir,
    target_size=(32, 32),
    batch_size=64,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 8003 images belonging to 10 classes.
# Found 1997 images belonging to 10 classes.
# /usr/local/lib/python3.12/dist-packages/keras/src/legacy/preprocessing/image.py:146: UserWarning: Using ".tiff" files with multiple bands will cause distortion. Please verify your output.
#   warnings.warn(

# %%
model = models.Sequential([
    layers.Conv2D(64, (3,3), activation='relu', padding='same', input_shape=(32,32,3)),
    layers.BatchNormalization(),
    layers.Conv2D(64, (3,3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2,2)),
    layers.Dropout(0.25),

    layers.Conv2D(128, (3,3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.Conv2D(128, (3,3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2,2)),
    layers.Dropout(0.35),

    layers.Conv2D(256, (3,3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.Conv2D(256, (3,3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2,2)),
    layers.Dropout(0.45),

    layers.Flatten(),
    layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    layers.BatchNormalization(),
    layers.Dropout(0.5),
    layers.Dense(10, activation='softmax')
])

optimizer = optimizers.Adam(learning_rate=0.0007)
model.compile(
    optimizer=optimizer,
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    metrics=['accuracy']
)

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_12 (Conv2D)              │ (None, 32, 32, 64)     │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_14          │ (None, 32, 32, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_13 (Conv2D)              │ (None, 32, 32, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_15          │ (None, 32, 32, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_14 (Conv2D)              │ (None, 16, 16, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_16          │ (None, 16, 16, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_15 (Conv2D)              │ (None, 16, 16, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_17          │ (None, 16, 16, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_16 (Conv2D)              │ (None, 8, 8, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_18          │ (None, 8, 8, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_17 (Conv2D)              │ (None, 8, 8, 256)      │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_19          │ (None, 8, 8, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 512)            │     2,097,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_20          │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 10)             │         5,130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,253,834 (12.41 MB)
#  Trainable params: 3,251,018 (12.40 MB)
#  Non-trainable params: 2,816 (11.00 KB)

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=3, min_lr=1e-5)

history = model.fit(
    train_generator,
    epochs=75,
    validation_data=val_generator,
    callbacks=[early_stop, reduce_lr]
)
# Out:
# Epoch 1/75
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 31s 152ms/step - accuracy: 0.1979 - loss: 3.9683 - val_accuracy: 0.1007 - val_loss: 4.1581 - learning_rate: 7.0000e-04
# Epoch 2/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 95ms/step - accuracy: 0.2949 - loss: 3.2718 - val_accuracy: 0.1042 - val_loss: 4.3001 - learning_rate: 7.0000e-04
# Epoch 3/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 97ms/step - accuracy: 0.3389 - loss: 2.9728 - val_accuracy: 0.1923 - val_loss: 3.3482 - learning_rate: 7.0000e-04
# Epoch 4/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 13s 100ms/step - accuracy: 0.3637 - loss: 2.8420 - val_accuracy: 0.2784 - val_loss: 2.9971 - learning_rate: 7.0000e-04
# Epoch 5/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 97ms/step - accuracy: 0.3827 - loss: 2.7130 - val_accuracy: 0.4301 - val_loss: 2.5168 - learning_rate: 7.0000e-04
# Epoch 6/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 95ms/step - accuracy: 0.3845 - loss: 2.6681 - val_accuracy: 0.4457 - val_loss: 2.3919 - learning_rate: 7.0000e-04
# Epoch 7/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 97ms/step - accuracy: 0.4421 - loss: 2.4357 - val_accuracy: 0.4301 - val_loss: 2.3488 - learning_rate: 7.0000e-04
# Epoch 8/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 97ms/step - accuracy: 0.4411 - loss: 2.3655 - val_accuracy: 0.4352 - val_loss: 2.3446 - learning_rate: 7.0000e-04
# Epoch 9/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 96ms/step - accuracy: 0.4847 - loss: 2.2253 - val_accuracy: 0.3530 - val_loss: 2.4225 - learning_rate: 7.0000e-04
# Epoch 10/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 96ms/step - accuracy: 0.4566 - loss: 2.2285 - val_accuracy: 0.4832 - val_loss: 2.1767 - learning_rate: 7.0000e-04
# Epoch 11/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 96ms/step - accuracy: 0.5058 - loss: 2.0889 - val_accuracy: 0.5223 - val_loss: 2.0111 - learning_rate: 7.0000e-04
# Epoch 12/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 95ms/step - accuracy: 0.5283 - loss: 2.0070 - val_accuracy: 0.5128 - val_loss: 2.0453 - learning_rate: 7.0000e-04
# Epoch 13/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 94ms/step - accuracy: 0.5104 - loss: 1.9965 - val_accuracy: 0.5814 - val_loss: 1.8538 - learning_rate: 7.0000e-04
# Epoch 14/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 93ms/step - accuracy: 0.5500 - loss: 1.9089 - val_accuracy: 0.6024 - val_loss: 1.7709 - learning_rate: 7.0000e-04
# Epoch 15/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 95ms/step - accuracy: 0.5638 - loss: 1.8354 - val_accuracy: 0.5804 - val_loss: 1.8124 - learning_rate: 7.0000e-04
# Epoch 16/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 95ms/step - accuracy: 0.5695 - loss: 1.8129 - val_accuracy: 0.4912 - val_loss: 2.0126 - learning_rate: 7.0000e-04
# Epoch 17/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 96ms/step - accuracy: 0.5714 - loss: 1.7987 - val_accuracy: 0.6134 - val_loss: 1.7160 - learning_rate: 7.0000e-04
# Epoch 18/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 96ms/step - accuracy: 0.5907 - loss: 1.7443 - val_accuracy: 0.4522 - val_loss: 2.1343 - learning_rate: 7.0000e-04
# Epoch 19/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 96ms/step - accuracy: 0.5714 - loss: 1.7601 - val_accuracy: 0.6129 - val_loss: 1.7154 - learning_rate: 7.0000e-04
# Epoch 20/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 96ms/step - accuracy: 0.6128 - loss: 1.6812 - val_accuracy: 0.6239 - val_loss: 1.6409 - learning_rate: 7.0000e-04
# Epoch 21/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 96ms/step - accuracy: 0.6186 - loss: 1.6631 - val_accuracy: 0.6415 - val_loss: 1.6201 - learning_rate: 7.0000e-04
# Epoch 22/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 96ms/step - accuracy: 0.6244 - loss: 1.6541 - val_accuracy: 0.6034 - val_loss: 1.7064 - learning_rate: 7.0000e-04
# Epoch 23/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 96ms/step - accuracy: 0.6235 - loss: 1.6515 - val_accuracy: 0.6510 - val_loss: 1.5842 - learning_rate: 7.0000e-04
# Epoch 24/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 95ms/step - accuracy: 0.6422 - loss: 1.6085 - val_accuracy: 0.6264 - val_loss: 1.6681 - learning_rate: 7.0000e-04
# Epoch 25/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 95ms/step - accuracy: 0.6568 - loss: 1.5916 - val_accuracy: 0.6490 - val_loss: 1.5797 - learning_rate: 7.0000e-04
# Epoch 26/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 96ms/step - accuracy: 0.6663 - loss: 1.5653 - val_accuracy: 0.4882 - val_loss: 1.9958 - learning_rate: 7.0000e-04
# Epoch 27/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 97ms/step - accuracy: 0.6359 - loss: 1.6234 - val_accuracy: 0.5724 - val_loss: 1.8032 - learning_rate: 7.0000e-04
# Epoch 28/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 97ms/step - accuracy: 0.6388 - loss: 1.6373 - val_accuracy: 0.5348 - val_loss: 1.8430 - learning_rate: 7.0000e-04
# Epoch 29/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 96ms/step - accuracy: 0.6812 - loss: 1.5375 - val_accuracy: 0.6880 - val_loss: 1.4883 - learning_rate: 2.1000e-04
# Epoch 30/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 96ms/step - accuracy: 0.7138 - loss: 1.4655 - val_accuracy: 0.7196 - val_loss: 1.4304 - learning_rate: 2.1000e-04
# Epoch 31/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 97ms/step - accuracy: 0.7194 - loss: 1.4316 - val_accuracy: 0.6920 - val_loss: 1.4585 - learning_rate: 2.1000e-04
# Epoch 32/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 98ms/step - accuracy: 0.7212 - loss: 1.4216 - val_accuracy: 0.7151 - val_loss: 1.4059 - learning_rate: 2.1000e-04
# Epoch 33/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 96ms/step - accuracy: 0.7286 - loss: 1.3879 - val_accuracy: 0.7311 - val_loss: 1.3686 - learning_rate: 2.1000e-04
# Epoch 34/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 98ms/step - accuracy: 0.7347 - loss: 1.3666 - val_accuracy: 0.7316 - val_loss: 1.3444 - learning_rate: 2.1000e-04
# Epoch 35/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 96ms/step - accuracy: 0.7422 - loss: 1.3373 - val_accuracy: 0.7236 - val_loss: 1.3640 - learning_rate: 2.1000e-04
# Epoch 36/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 98ms/step - accuracy: 0.7533 - loss: 1.3094 - val_accuracy: 0.7206 - val_loss: 1.3633 - learning_rate: 2.1000e-04
# Epoch 37/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 97ms/step - accuracy: 0.7409 - loss: 1.3117 - val_accuracy: 0.7256 - val_loss: 1.3293 - learning_rate: 2.1000e-04
# Epoch 38/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 97ms/step - accuracy: 0.7306 - loss: 1.3207 - val_accuracy: 0.7361 - val_loss: 1.2952 - learning_rate: 2.1000e-04
# Epoch 39/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 96ms/step - accuracy: 0.7507 - loss: 1.2806 - val_accuracy: 0.7236 - val_loss: 1.3162 - learning_rate: 2.1000e-04
# Epoch 40/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 96ms/step - accuracy: 0.7521 - loss: 1.2760 - val_accuracy: 0.7361 - val_loss: 1.3261 - learning_rate: 2.1000e-04
# Epoch 41/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 95ms/step - accuracy: 0.7468 - loss: 1.2757 - val_accuracy: 0.7466 - val_loss: 1.2658 - learning_rate: 2.1000e-04
# Epoch 42/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 95ms/step - accuracy: 0.7580 - loss: 1.2521 - val_accuracy: 0.7376 - val_loss: 1.3047 - learning_rate: 2.1000e-04
# Epoch 43/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 95ms/step - accuracy: 0.7594 - loss: 1.2292 - val_accuracy: 0.7386 - val_loss: 1.2904 - learning_rate: 2.1000e-04
# Epoch 44/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 96ms/step - accuracy: 0.7629 - loss: 1.2388 - val_accuracy: 0.7266 - val_loss: 1.2783 - learning_rate: 2.1000e-04
# Epoch 45/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 96ms/step - accuracy: 0.7753 - loss: 1.2071 - val_accuracy: 0.7596 - val_loss: 1.2310 - learning_rate: 6.3000e-05
# Epoch 46/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 95ms/step - accuracy: 0.7797 - loss: 1.1911 - val_accuracy: 0.7546 - val_loss: 1.2339 - learning_rate: 6.3000e-05
# Epoch 47/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 94ms/step - accuracy: 0.7850 - loss: 1.1779 - val_accuracy: 0.7521 - val_loss: 1.2320 - learning_rate: 6.3000e-05
# Epoch 48/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 96ms/step - accuracy: 0.8014 - loss: 1.1594 - val_accuracy: 0.7611 - val_loss: 1.2187 - learning_rate: 6.3000e-05
# Epoch 49/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 94ms/step - accuracy: 0.7925 - loss: 1.1642 - val_accuracy: 0.7692 - val_loss: 1.2118 - learning_rate: 6.3000e-05
# Epoch 50/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 95ms/step - accuracy: 0.7961 - loss: 1.1543 - val_accuracy: 0.7586 - val_loss: 1.2127 - learning_rate: 6.3000e-05
# Epoch 51/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 95ms/step - accuracy: 0.7892 - loss: 1.1585 - val_accuracy: 0.7661 - val_loss: 1.2052 - learning_rate: 6.3000e-05
# Epoch 52/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 94ms/step - accuracy: 0.7965 - loss: 1.1365 - val_accuracy: 0.7626 - val_loss: 1.2084 - learning_rate: 6.3000e-05
# Epoch 53/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 94ms/step - accuracy: 0.8124 - loss: 1.1134 - val_accuracy: 0.7561 - val_loss: 1.2175 - learning_rate: 6.3000e-05
# Epoch 54/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 94ms/step - accuracy: 0.8096 - loss: 1.1258 - val_accuracy: 0.7697 - val_loss: 1.1875 - learning_rate: 6.3000e-05
# Epoch 55/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 95ms/step - accuracy: 0.8044 - loss: 1.1125 - val_accuracy: 0.7591 - val_loss: 1.2114 - learning_rate: 6.3000e-05
# Epoch 56/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 94ms/step - accuracy: 0.8005 - loss: 1.1124 - val_accuracy: 0.7767 - val_loss: 1.1750 - learning_rate: 6.3000e-05
# Epoch 57/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 94ms/step - accuracy: 0.7957 - loss: 1.1306 - val_accuracy: 0.7672 - val_loss: 1.1891 - learning_rate: 6.3000e-05
# Epoch 58/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 94ms/step - accuracy: 0.8055 - loss: 1.1113 - val_accuracy: 0.7666 - val_loss: 1.1872 - learning_rate: 6.3000e-05
# Epoch 59/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 95ms/step - accuracy: 0.8143 - loss: 1.0919 - val_accuracy: 0.7687 - val_loss: 1.1874 - learning_rate: 6.3000e-05
# Epoch 60/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 94ms/step - accuracy: 0.8173 - loss: 1.0813 - val_accuracy: 0.7471 - val_loss: 1.2027 - learning_rate: 1.8900e-05
# Epoch 61/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 96ms/step - accuracy: 0.8174 - loss: 1.0884 - val_accuracy: 0.7651 - val_loss: 1.1789 - learning_rate: 1.8900e-05
# Epoch 62/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 94ms/step - accuracy: 0.8082 - loss: 1.0880 - val_accuracy: 0.7747 - val_loss: 1.1771 - learning_rate: 1.8900e-05
# Epoch 63/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 97ms/step - accuracy: 0.8213 - loss: 1.0840 - val_accuracy: 0.7702 - val_loss: 1.1788 - learning_rate: 1.0000e-05
# Epoch 64/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 13s 100ms/step - accuracy: 0.8231 - loss: 1.0727 - val_accuracy: 0.7717 - val_loss: 1.1596 - learning_rate: 1.0000e-05
# Epoch 65/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 13s 102ms/step - accuracy: 0.8233 - loss: 1.0720 - val_accuracy: 0.7777 - val_loss: 1.1710 - learning_rate: 1.0000e-05
# Epoch 66/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - accuracy: 0.8135 - loss: 1.0759 - val_accuracy: 0.7767 - val_loss: 1.1654 - learning_rate: 1.0000e-05
# Epoch 67/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 98ms/step - accuracy: 0.8110 - loss: 1.0840 - val_accuracy: 0.7727 - val_loss: 1.1689 - learning_rate: 1.0000e-05
# Epoch 68/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 94ms/step - accuracy: 0.8132 - loss: 1.0868 - val_accuracy: 0.7782 - val_loss: 1.1584 - learning_rate: 1.0000e-05
# Epoch 69/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 94ms/step - accuracy: 0.8205 - loss: 1.0757 - val_accuracy: 0.7782 - val_loss: 1.1576 - learning_rate: 1.0000e-05
# Epoch 70/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 93ms/step - accuracy: 0.8240 - loss: 1.0731 - val_accuracy: 0.7752 - val_loss: 1.1693 - learning_rate: 1.0000e-05
# Epoch 71/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 95ms/step - accuracy: 0.8282 - loss: 1.0563 - val_accuracy: 0.7651 - val_loss: 1.1702 - learning_rate: 1.0000e-05
# Epoch 72/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 93ms/step - accuracy: 0.8218 - loss: 1.0745 - val_accuracy: 0.7747 - val_loss: 1.1667 - learning_rate: 1.0000e-05
# Epoch 73/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 93ms/step - accuracy: 0.8228 - loss: 1.0742 - val_accuracy: 0.7737 - val_loss: 1.1803 - learning_rate: 1.0000e-05
# Epoch 74/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 93ms/step - accuracy: 0.8136 - loss: 1.0768 - val_accuracy: 0.7651 - val_loss: 1.1774 - learning_rate: 1.0000e-05
# Epoch 75/75
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 98ms/step - accuracy: 0.8233 - loss: 1.0594 - val_accuracy: 0.7767 - val_loss: 1.1571 - learning_rate: 1.0000e-05

# %%
plt.figure(figsize=(10,5))
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(10,5))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
val_loss, val_acc = model.evaluate(val_generator)
print(f"Validation Accuracy: {val_acc*100:.2f}%")
print(f"Validation Loss: {val_loss:.4f}")
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - accuracy: 0.7988 - loss: 1.1450
# Validation Accuracy: 80.02%
# Validation Loss: 1.1345
